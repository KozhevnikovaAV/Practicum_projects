# %% [markdown]
# # Построение дашбордов в Tableau

# %% [markdown]
# Задача: исследование истории TED-конференций с помощью Tableau

# %% [markdown]
# доступно для исследования: tableau_project_data_1.csv, tableau_project_data_2.csv, tableau_project_data_3.csv (файлы, хранящие данные о выстплениях), tableau_project_event_dict.csv (справочник конференций) и tableau_project_speakers_dict.csv (справочник авторов выступления)

# %% [markdown]
# ## История выступлений

# %% [markdown]
# ### Создание листа «Выступления по странам» с визуализацией типа mapс процентным показателей выстплений в каждой из стран

# %% [markdown]
# ### Создание листа «Выступления по годам» с визуализацией типа area charts

# %% [markdown]
# ### С копии предыдущего листа сделайте новый лист «Процент выступлений по тематикам»

# %% [markdown]
# ### Фильтр по полю Film Date, примененный ко всем визуализациям

# %% [markdown]
# ### Создание дашборад «История выступлений» по макету

# %% [markdown]
# ## Тематика выступлений

# %% [markdown]
# ### Создание листа «Выступления по тематике» с круговой диаграммой

# %% [markdown]
# ### Создание листа «Тематики и страны» с визуализацией типа highlight table

# %% [markdown]
# ### Создание листа «Аплодисменты по тематикам» с диаграммой размаха

# %% [markdown]
# ### Создание копии предыдущего листа - «Смех по тематикам»

# %% [markdown]
# ### Создание двух новых листов с гистограммами длительности выступлений («Гистограмма длительности») и числа просмотров («Гистограмма просмотров»)

# %% [markdown]
# ### Создание нового листа «Связь длительности с просмотрами»

# %% [markdown]
# ### Создание дашборда «Тематики выступлений» по макету

# %% [markdown]
# ## Авторы выступлений

# %% [markdown]
# ### Создание сета, который объединит наиболее популярные области деятельности авторов

# %% [markdown]
# ### Создание листа «Области деятельности авторов» с пузырьковой диаграммой

# %% [markdown]
# ### Создание вычисляемого поля Talks by Author, которое покажет максимальное количество выступлений у автора

# %% [markdown]
# ### Создание листа «Распределение числа выступлений» со столбчатой диаграммой

# %% [markdown]
# ### Создание листа «Авторы по числу выступлений»

# %% [markdown]
# ### Создание листа «Выступления и число просмотров»

# %% [markdown]
# ### Создание дашборда «Авторы выступлений» по макету

# %% [markdown]
# ## Дашборд на свободную тему

# %% [markdown]
# все выводы и наблюдния имеются на дашбордах

# %% [markdown]
# ссылка на проект: https://public.tableau.com/app/profile/kozhevnikova.aleksandra/viz/projectted_17265954173220/TEDshows
